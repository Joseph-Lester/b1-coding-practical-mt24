# %%
# Add relevant Jupyter notebook extensions 
# %load_ext autoreload
# %autoreload 2

# %%
# You can double-check your Python path like this...
import sys  
print(sys.path)
# Out:
# ['/Users/joelester/Library/Mobile Documents/com~apple~CloudDocs/Oxford/Engineering/3rd Year/B1/Scientific Coding/B1 Assignment/b1-coding-practical-mt24/notebooks', '/Users/joelester/Library/Mobile Documents/com~apple~CloudDocs/Oxford/Engineering/3rd Year/B1/Scientific Coding/B1 Assignment/b1-coding-practical-mt24', '/Users/joelester/Library/Mobile Documents/com~apple~CloudDocs/Oxford/Engineering/3rd Year/B1/Scientific Coding/B1 Assignment/b1-coding-practical-mt24/notebooks', '/Users/joelester/anaconda3/lib/python311.zip', '/Users/joelester/anaconda3/lib/python3.11', '/Users/joelester/anaconda3/lib/python3.11/lib-dynload', '', '/Users/joelester/anaconda3/lib/python3.11/site-packages', '/Users/joelester/anaconda3/lib/python3.11/site-packages/aeosa']

# %% [markdown]
# # Simulate closed-loop
# After implementing your control functionality, you can simulate the closed-loop with code that looks something like this...

# %%
# Import relevant modules
from uuv_mission.dynamic import Submarine,ClosedLoop,Mission
from uuv_mission.control import Controller

sub = Submarine()
my_controller = Controller()
# Instantiate your controller (depending on your implementation)
closed_loop = ClosedLoop(sub, my_controller)
mission = Mission.from_csv("../data/mission.csv") # You must implement this method in the Mission class
trajectory = closed_loop.simulate_with_random_disturbances(mission)
trajectory.plot_completed_mission(mission)
